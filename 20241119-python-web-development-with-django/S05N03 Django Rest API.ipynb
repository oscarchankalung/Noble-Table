# %%
import requests

# %%
url = "http://127.0.0.1:8000/api/v1/restaurants/"

# %%
response = requests.get(url)

# %%
data = response.json()

# %%
data
# Out:
# [{'name': 'Olio e Più', 'cuisine': 'Pizza', 'city': 'New York'},
#  {'name': 'Valerie', 'cuisine': 'New American', 'city': 'New York'},
#  {'name': 'Kalye', 'cuisine': 'Filipino', 'city': 'New York'},
#  {'name': 'The Osprey', 'cuisine': 'Australian', 'city': 'Brooklyn'},
#  {'name': 'Raku', 'cuisine': 'Japanese', 'city': 'New York'},
#  {'name': 'Cafe Mogador', 'cuisine': 'Moroccan', 'city': 'Brooklyn'},
#  {'name': 'Soothr', 'cuisine': 'Thai', 'city': 'New York'},
#  {'name': 'Zou Zou’s', 'cuisine': 'Mediterranean', 'city': 'New York'},
#  {'name': 'Wah Fung No 1', 'cuisine': 'Fast Food', 'city': 'New York'},
#  {'name': 'Crab House NYC', 'cuisine': 'Buffets', 'city': 'New York'},
#  {'name': 'FERNS', 'cuisine': 'Cocktail Bars', 'city': 'New York'},
#  {'name': 'Blue Willow 夜来湘', 'cuisine': 'Szechuan', 'city': 'New York'},
#  {'name': 'The Cabin NYC', 'cuisine': 'New American', 'city': 'New York'},
#  {'name': 'Golden Diner', 'cuisine': 'Diners', 'city': 'New York'},
# ...
